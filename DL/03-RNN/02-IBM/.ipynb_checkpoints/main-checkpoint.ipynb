# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

dataset = pd.read_csv('data/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])

dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# Checking for missing values
training_set = dataset[:'2016'].iloc[:,1:2].values
test_set = dataset['2017':].iloc[:,1:2].values

# %%
# We have chosen 'High' attribute for prices. Let's see what it looks like
dataset["High"][:'2016'].plot(figsize=(16,4),legend=True)
dataset["High"]['2017':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2017)','Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60,2769):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# 3 Demensional array
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

rl = ReduceLROnPlateau(monitor='loss', patience=5, verbose=1)

# %%
# The LSTM architecture
regressor = Sequential()

# First LSTM layer with Dropout regularisation
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.5))

# Second LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Third LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Fourth LSTM layer
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

# The output layer
regressor.add(Dense(units=1))

# Compiling the RNN
regressor.compile(optimizer='rmsprop',loss='mean_squared_error', metrics=['mean_squared_error'])

# %%
# Fitting to the training set
history = regressor.fit(X_train, Y_train, epochs=50,batch_size=32, callbacks=[rl])

# Saving weights
regressor.save_weights('weights.h5')
# Out:
# Epoch 1/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0222 - mean_squared_error: 0.0222
# Epoch 2/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 3/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 4/50
# 85/85 [==============================] - 10s 120ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 5/50
# 85/85 [==============================] - 10s 120ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 6/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 7/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 8/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 9/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 10/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 11/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 12/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 13/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 14/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 15/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 16/50
# 85/85 [==============================] - 10s 123ms/step - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 17/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 18/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 19/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 20/50
# 85/85 [==============================] - 11s 124ms/step - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 21/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 22/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 23/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 24/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 25/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 26/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 27/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 28/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 29/50
# 85/85 [==============================] - 10s 123ms/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 30/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 31/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 32/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 33/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 34/50
# 85/85 [==============================] - 10s 123ms/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 35/50
# 85/85 [==============================] - 10s 124ms/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 36/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 37/50
# 85/85 [==============================] - 11s 124ms/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 38/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 39/50
# 85/85 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 40/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 41/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 42/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 43/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 44/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 45/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 46/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 47/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 48/50
# 85/85 [==============================] - ETA: 0s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 85/85 [==============================] - 11s 126ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 49/50
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 50/50
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0013 - mean_squared_error: 0.0013

# %%
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %%
regressor.load_weights('weights.h5')

# %%
X_test = []
Y_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
    Y_test.append(inputs[i, 0])
    
X_test = np.array(X_test)
Y_test = np.array(Y_test)
Y_test = Y_test.reshape(-1,1)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
Y_pred = regressor.predict(X_test)
Y_pred = sc.inverse_transform(Y_pred)

# %%
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()
    
plot_predictions(Y_test, Y_pred)

# %%
mse = mean_squared_error(Y_test, Y_pred)

mse = math.sqrt(mse)
mse
# Out:
# 158.57168162999184

# %%
Y_pred.shape
# Out:
# (251, 1)

# %%
X_test.shape
# Out:
# (251, 60, 1)

# %%
Y_test.shape
# Out:
# (251,)

# %%
Y_pred
# Out:
# array([[167.3649 ],
#        [167.31232],
#        [167.76256],
#        [168.36511],
#        [168.97922],
#        [169.44753],
#        [169.43874],
#        [169.07883],
#        [168.66093],
#        [168.41444],
#        [168.28915],
#        [168.31575],
#        [168.22816],
#        [168.60707],
#        [169.3603 ],
#        [170.99629],
#        [173.4465 ],
#        [175.77654],
#        [177.52853],
#        [178.22751],
#        [177.95277],
#        [177.25998],
#        [176.42949],
#        [175.95236],
#        [175.75847],
#        [176.19298],
#        [176.7335 ],
#        [177.2105 ],
#        [177.72238],
#        [178.34834],
#        [178.96982],
#        [179.76714],
#        [180.68263],
#        [181.28076],
#        [181.42627],
#        [181.39314],
#        [181.51054],
#        [181.56758],
#        [181.52466],
#        [181.33258],
#        [181.4164 ],
#        [181.57452],
#        [181.6293 ],
#        [181.54218],
#        [181.44371],
#        [181.31969],
#        [180.92432],
#        [180.4682 ],
#        [179.85226],
#        [179.04834],
#        [178.19354],
#        [177.93307],
#        [177.7528 ],
#        [177.4761 ],
#        [177.17506],
#        [176.72777],
#        [176.36754],
#        [176.1182 ],
#        [175.75017],
#        [175.49254],
#        [175.2821 ],
#        [175.14244],
#        [175.12604],
#        [175.16942],
#        [175.24063],
#        [175.53937],
#        [175.44263],
#        [174.97906],
#        [174.34059],
#        [173.52565],
#        [172.75339],
#        [172.19418],
#        [171.85907],
#        [171.76587],
#        [170.29088],
#        [168.06963],
#        [165.85463],
#        [164.04597],
#        [162.90308],
#        [162.19713],
#        [161.70071],
#        [161.37813],
#        [161.1649 ],
#        [160.87268],
#        [160.54562],
#        [160.20645],
#        [159.34964],
#        [157.89151],
#        [156.28064],
#        [154.8113 ],
#        [153.512  ],
#        [152.54326],
#        [152.03862],
#        [152.25711],
#        [152.8984 ],
#        [153.11147],
#        [153.09502],
#        [153.05356],
#        [153.17699],
#        [153.23521],
#        [153.3674 ],
#        [153.412  ],
#        [153.31256],
#        [153.16182],
#        [153.0343 ],
#        [153.00673],
#        [153.00137],
#        [152.985  ],
#        [153.18166],
#        [153.25899],
#        [153.44388],
#        [154.20215],
#        [154.91576],
#        [155.27364],
#        [155.28392],
#        [155.23393],
#        [155.28387],
#        [155.3237 ],
#        [155.40067],
#        [155.35593],
#        [155.1745 ],
#        [155.13347],
#        [155.1534 ],
#        [155.22462],
#        [155.34286],
#        [155.25296],
#        [155.28503],
#        [155.41313],
#        [155.21205],
#        [154.74019],
#        [154.28517],
#        [153.92796],
#        [153.79991],
#        [153.83308],
#        [154.00996],
#        [154.1043 ],
#        [154.16927],
#        [153.52904],
#        [152.26935],
#        [150.7483 ],
#        [149.26892],
#        [148.18922],
#        [147.40561],
#        [146.72075],
#        [146.11075],
#        [145.62338],
#        [145.41637],
#        [145.36124],
#        [145.37828],
#        [145.42305],
#        [145.41403],
#        [144.96954],
#        [144.17134],
#        [143.39522],
#        [142.85783],
#        [142.60623],
#        [142.65569],
#        [142.79033],
#        [142.90106],
#        [142.6678 ],
#        [142.10355],
#        [141.57608],
#        [141.53938],
#        [141.96622],
#        [142.64757],
#        [143.37097],
#        [143.7584 ],
#        [143.80159],
#        [143.71295],
#        [143.74553],
#        [143.85858],
#        [144.00343],
#        [144.16039],
#        [144.0433 ],
#        [144.07635],
#        [144.47752],
#        [145.03412],
#        [145.55136],
#        [145.71771],
#        [145.66235],
#        [145.438  ],
#        [145.32033],
#        [145.3339 ],
#        [145.36948],
#        [145.4662 ],
#        [145.82492],
#        [146.21431],
#        [146.33229],
#        [146.2015 ],
#        [146.16275],
#        [146.30148],
#        [146.49583],
#        [146.75272],
#        [146.8854 ],
#        [147.05408],
#        [147.44223],
#        [147.8331 ],
#        [148.01761],
#        [148.01608],
#        [147.88948],
#        [147.63538],
#        [149.79558],
#        [153.35295],
#        [157.06215],
#        [159.95209],
#        [161.22166],
#        [160.71466],
#        [159.12968],
#        [157.2692 ],
#        [155.70392],
#        [154.72365],
#        [154.27954],
#        [154.12912],
#        [153.95166],
#        [153.45842],
#        [152.781  ],
#        [152.19289],
#        [151.8054 ],
#        [151.46042],
#        [150.85399],
#        [150.15636],
#        [149.51904],
#        [149.21278],
#        [149.27513],
#        [149.84167],
#        [150.69583],
#        [151.50493],
#        [152.05563],
#        [152.38353],
#        [152.61461],
#        [152.88918],
#        [153.29852],
#        [153.8275 ],
#        [154.63263],
#        [155.45876],
#        [156.01215],
#        [155.9653 ],
#        [155.65149],
#        [155.45213],
#        [155.75064],
#        [156.1352 ],
#        [156.14635],
#        [155.65732],
#        [155.03178],
#        [154.5021 ],
#        [154.10815],
#        [153.78998],
#        [153.4812 ],
#        [153.36835],
#        [153.30005],
#        [153.40242]], dtype=float32)
