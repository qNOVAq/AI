# %%
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential

data = pd.read_csv('pulsar_stars.csv')
data.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# 1                            -0.515088                   1.677258
# 2                             1.051164                   3.121237
# 3                            -0.636238                   3.642977
# 4                             1.123492                   1.178930
#
#     Standard deviation of the DM-SNR curve  \
# 0                                19.110426
# 1                                14.860146
# 2                                21.744669
# 3                                20.959280
# 4                                11.468720
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                              7.975532                      74.242225
# 1                             10.576487                     127.393580
# 2                              7.735822                      63.171909
# 3                              6.896499                      53.593661
# 4                             14.269573                     252.567306
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
x = data.drop('target_class', 1)
y = data.target_class

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score

def build_model():
    
    model = Sequential()

    model.add(Dense(20, activation='relu', input_dim=x.shape[1]))
    model.add(Dropout(0.2))

    model.add(Dense(20, activation='relu'))

    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

classifier = KerasClassifier(build_fn= build_model, epochs=12)

scores = cross_val_score(estimator=classifier, X= x, y= y, cv=3)
# Out:
# Epoch 1/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.3466 - accuracy: 0.9470
# Epoch 2/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1106 - accuracy: 0.9713
# Epoch 3/12
# 373/373 [==============================] - 1s 1ms/step - loss: 0.0992 - accuracy: 0.9752
# Epoch 4/12
# 373/373 [==============================] - 1s 1ms/step - loss: 0.0858 - accuracy: 0.9785
# Epoch 5/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0874 - accuracy: 0.9773
# Epoch 6/12
# 373/373 [==============================] - 1s 1ms/step - loss: 0.0813 - accuracy: 0.9775
# Epoch 7/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0815 - accuracy: 0.9780
# Epoch 8/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0784 - accuracy: 0.9785
# Epoch 9/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0794 - accuracy: 0.9785
# Epoch 10/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0779 - accuracy: 0.9790
# Epoch 11/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0769 - accuracy: 0.9785
# Epoch 12/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0760 - accuracy: 0.9790
# 187/187 [==============================] - 0s 1ms/step - loss: 0.1399 - accuracy: 0.9596
# Epoch 1/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.5560 - accuracy: 0.9304
# Epoch 2/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1284 - accuracy: 0.9634
# Epoch 3/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1137 - accuracy: 0.9656
# Epoch 4/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1056 - accuracy: 0.9687
# Epoch 5/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1057 - accuracy: 0.9697
# Epoch 6/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0998 - accuracy: 0.9714
# Epoch 7/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0991 - accuracy: 0.9716
# Epoch 8/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0987 - accuracy: 0.9716
# Epoch 9/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0941 - accuracy: 0.9717
# Epoch 10/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0911 - accuracy: 0.9732
# Epoch 11/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.0921 - accuracy: 0.9728
# Epoch 12/12
# 373/373 [==============================] - 0s 1ms/step - loss: 0.0915 - accuracy: 0.9724
# 187/187 [==============================] - 0s 946us/step - loss: 0.0962 - accuracy: 0.9728
# Epoch 1/12
# 373/373 [==============================] - 1s 2ms/step - loss: 4.5307 - accuracy: 0.8209
# Epoch 2/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.4299 - accuracy: 0.9243
# Epoch 3/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.2300 - accuracy: 0.9376
# Epoch 4/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1973 - accuracy: 0.9418
# Epoch 5/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1708 - accuracy: 0.9514
# Epoch 6/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1605 - accuracy: 0.9527
# Epoch 7/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1494 - accuracy: 0.9568
# Epoch 8/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1463 - accuracy: 0.9579
# Epoch 9/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1396 - accuracy: 0.9590
# Epoch 10/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1313 - accuracy: 0.9625
# Epoch 11/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1255 - accuracy: 0.9628
# Epoch 12/12
# 373/373 [==============================] - 1s 2ms/step - loss: 0.1264 - accuracy: 0.9630
# 187/187 [==============================] - 0s 1ms/step - loss: 0.0831 - accuracy: 0.9859

# %%
mean = scores.mean()
mean
# Out:
# 0.97279026110967
