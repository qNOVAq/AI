# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
plt.style.use('ggplot')
warnings.filterwarnings('ignore')

data = pd.read_csv('Melbourne_housing_FULL.csv')
data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
data.describe().T
# Out:
#                  count          mean            std          min  \
# Rooms          34857.0  3.031012e+00       0.969933      1.00000
# Price          27247.0  1.050173e+06  641467.130105  85000.00000
# Distance       34856.0  1.118493e+01       6.788892      0.00000
# Postcode       34856.0  3.116063e+03     109.023903   3000.00000
# Bedroom2       26640.0  3.084647e+00       0.980690      0.00000
# Bathroom       26631.0  1.624798e+00       0.724212      0.00000
# Car            26129.0  1.728845e+00       1.010771      0.00000
# Landsize       23047.0  5.935990e+02    3398.841946      0.00000
# BuildingArea   13742.0  1.602564e+02     401.267060      0.00000
# YearBuilt      15551.0  1.965290e+03      37.328178   1196.00000
# Lattitude      26881.0 -3.781063e+01       0.090279    -38.19043
# Longtitude     26881.0  1.450019e+02       0.120169    144.42379
# Propertycount  34854.0  7.572888e+03    4428.090313     83.00000
#
# ...

# %%
# Checking for missing values
data.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
# Correlation heatmap
plt.figure(figsize=(15,12))
sns.heatmap(data.corr(), annot=True).set_title('Correlation heatmap of the dataset')
# Out:
# Text(0.5, 1.0, 'Correlation heatmap of the dataset')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
# Droppping low correlated column
data = data.drop(['Longtitude', 'Lattitude', 'Address', 'Date', 'Postcode', ], 1)

# %%
# Basic featrure engineering
data['Total_Rooms'] = data['Rooms'] + data['Bedroom2'] /2
data['Bathroom per bedroom'] = data['Bedroom2'] / data['Bathroom']

# %%
# Filling missing values with their mean and median
from sklearn.impute import SimpleImputer
si = SimpleImputer(strategy='most_frequent')

data['Price'] = data['Price'].fillna(data['Price'].mean())
data['Distance'] = data['Distance'].fillna(data['Distance'].mean())
data['Bedroom2'] = data['Bedroom2'].fillna(data['Bedroom2'].mean())
data['Bathroom'] = data['Bathroom'].fillna(data['Bathroom'].mean())
data['Car'] = data['Car'].fillna(data['Car'].mean())
data['Landsize'] = data['Landsize'].fillna(data['Landsize'].mean())
data['BuildingArea'] = data['BuildingArea'].fillna(data['BuildingArea'].mean())
data['YearBuilt'] = data['YearBuilt'].fillna(data['YearBuilt'].mean())
data['Propertycount'] = data['Propertycount'].fillna(data['Propertycount'].mean())
data['Total_Rooms'] = data['Total_Rooms'].fillna(data['Total_Rooms'].mean())
data['Bathroom per bedroom'] = data['Price'].fillna(data['Price'].mean())

data.iloc[:, 13:14] = si.fit_transform(data.iloc[:, 13:14])
data.iloc[:, 14:15] = si.fit_transform(data.iloc[:, 14:15])

data.isnull().sum()
# Out:
# Suburb                  0
# Rooms                   0
# Type                    0
# Price                   0
# Method                  0
# SellerG                 0
# Distance                0
# Bedroom2                0
# Bathroom                0
# Car                     0
# Landsize                0
# BuildingArea            0
# YearBuilt               0
# CouncilArea             0
# Regionname              0
# Propertycount           0
# Total_Rooms             0
# Bathroom per bedroom    0
# dtype: int64

# %%
# Basic EDA
plt.figure(figsize=(15,12))
sns.distplot(data.Price, color='red').set_title("Ditribution of Price")
# Out:
# Text(0.5, 1.0, 'Ditribution of Price')

# %%
plt.figure(figsize=(15,12))
sns.distplot(data.Distance, color='green').set_title('Distribution of ')
# Out:
# Text(0.5, 1.0, 'Distribution of ')

# %%
plt.figure(figsize=(15,12))
sns.distplot(data.Propertycount, color='blue').set_title('Distribution of Property')
# Out:
# Text(0.5, 1.0, 'Distribution of Property')

# %%
plt.figure(figsize=(15,12))
sns.distplot(data.Total_Rooms, color='magenta').set_title('Distribution of the Total Rooms')
# Out:
# Text(0.5, 1.0, 'Distribution of the Total Rooms')

# %%
plt.figure(figsize=(15,12))
sns.distplot(data['Bathroom per bedroom'], color='orange').set_title('Distribution of Bathroom per bedtroom')
# Out:
# Text(0.5, 1.0, 'Distribution of Bathroom per bedtroom')

# %%
plt.figure(figsize=(15,12))
sns.countplot(data.Type, saturation=0.9).set_title('Count of the type')
# Out:
# Text(0.5, 1.0, 'Count of the type')

# %%
plt.figure(figsize=(20,12))
sns.countplot(data.Regionname, saturation=0.9).set_title('Count of Regions')
# Out:
# Text(0.5, 1.0, 'Count of Regions')

# %%
# Encoding categorical variables
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

categorical = data.select_dtypes(include='object')
categorical_cols = categorical.columns

for column in categorical_cols:
    data[column] = encoder.fit_transform(data[column])

# %%
# Converting non float to float64
non_float = data.select_dtypes(exclude='float64')
non_float_cols = non_float.columns

for column in non_float_cols:
    data[column] = data[column].astype('float64')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Suburb                34857 non-null  float64
#  1   Rooms                 34857 non-null  float64
#  2   Type                  34857 non-null  float64
#  3   Price                 34857 non-null  float64
#  4   Method                34857 non-null  float64
#  5   SellerG               34857 non-null  float64
#  6   Distance              34857 non-null  float64
#  7   Bedroom2              34857 non-null  float64
#  8   Bathroom              34857 non-null  float64
#  9   Car                   34857 non-null  float64
#  10  Landsize              34857 non-null  float64
#  11  BuildingArea          34857 non-null  float64
#  12  YearBuilt             34857 non-null  float64
#  13  CouncilArea           34857 non-null  float64
# ...

# %%
# Splitting to dependant and independant
X = data.drop('Price', 1).values
y = data.Price.values

# %%
# Splitting to train and test/validation sets
from sklearn.model_selection import KFold
kf = KFold()

for train_index, test_index in kf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    
print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'Y_train shape: {Y_train.shape}')
print(f'X_test shape: {Y_test.shape}')
# Out:
# X_train shape: (27886, 17)
# X_test shape: (6971, 17)
# Y_train shape: (27886,)
# X_test shape: (6971,)

# %%
# Normalizing the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting to the model
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error

estimators = [LinearRegression(), RandomForestRegressor(), DecisionTreeRegressor(),
             XGBRegressor()]

for model in estimators:
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)

    accuracy = model.score(X_test, Y_test)
    
    mse = mean_absolute_error(Y_test, Y_pred)
    print(f'{model} Accuracy: {accuracy}')
    print(f'{model} Error: {mse}')
    print('='*100)
# Out:
# LinearRegression() Accuracy: 1.0
# LinearRegression() Error: 1.8677553326306187e-09
# ...
# RandomForestRegressor() Accuracy: 0.9999140991021878
# RandomForestRegressor() Error: 227.91353895409807
# ...
# DecisionTreeRegressor() Accuracy: 0.9999140962191652
# DecisionTreeRegressor() Error: 269.94319323516567
# ...
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None) Accuracy: 0.9999364474322228
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
# ...
