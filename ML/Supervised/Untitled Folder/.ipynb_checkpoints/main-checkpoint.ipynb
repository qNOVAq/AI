# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
COLOR = 'black'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR
mpl.rcParams['font.size'] = 25
plt.rcParams["font.family"] = "times new roman"
data = pd.read_csv('data.csv')

# %%
label = []
weeks = 'Week '
for i in range(1, 20):
    label.append(weeks + str(i))

# %%
plt.figure(figsize=(39,19))
plt.bar(label[0], data.iloc[:, 0], width=0.5)
plt.bar(label[1], data.iloc[:, 1], width=0.5)
plt.bar(label[2], data.iloc[:, 2], width=0.5)
plt.bar(label[3], data.iloc[:, 3], width=0.5)
plt.bar(label[4], data.iloc[:, 4], width=0.5)
plt.bar(label[5], data.iloc[:, 5], width=0.5)
plt.bar(label[6], data.iloc[:, 6], width=0.5)
plt.bar(label[7], data.iloc[:, 7], width=0.5)
plt.bar(label[8], data.iloc[:, 8], width=0.5)
plt.bar(label[9], data.iloc[:, 9], width=0.5)
plt.bar(label[10], data.iloc[:, 10], width=0.5)
plt.bar(label[11], data.iloc[:, 11], width=0.5)
plt.bar(label[12], data.iloc[:, 12], width=0.5)
plt.bar(label[13], data.iloc[:, 13], width=0.5)
plt.bar(label[14], data.iloc[:, 14], width=0.5)
plt.bar(label[15], data.iloc[:, 15], width=0.5)
plt.bar(label[16], data.iloc[:, 16], width=0.5)
plt.bar(label[17], data.iloc[:, 17], width=0.5)
plt.bar(label[18], data.iloc[:, 18], width=0.5)

plt.title('Number of cases in Bahrain from 09 March - 18 July')
plt.ylabel('Number Of Cases')
plt.xlabel('Number Of Weeks')
plt.show()
