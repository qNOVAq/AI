# %%
import pandas as pd 
import numpy as np
data = pd.read_csv('pricerunner_washers.csv')
data.head()
# Out:
#    30131  \
# 0  30132
# 1  30133
# 2  30134
# 3  30135
# 4  30136
#
#   bosch wiw28300gb serie 6 8kg 1400rpm integrated washing machine white    6  \
# 0  bosch serie 6 wiw28300gb integrated 8 kg 1400 ...                       7
# 1                        bosch wiw28300gb/wiw28300gb                      98
# 2                         integrated washing machine                     347
# 3  bosch wiw28300gb serie 6 8kg 1400rpm integrate...                       3
# 4  bosch wiw28300gb integrated washer 1400rpm 8kg...                     131
#
#    41862  Bosch WIW28300GB  2620  Washing Machines
# 0  41862  Bosch WIW28300GB  2620  Washing Machines
# 1  41862  Bosch WIW28300GB  2620  Washing Machines
# 2  41862  Bosch WIW28300GB  2620  Washing Machines
# 3  41862  Bosch WIW28300GB  2620  Washing Machines
# 4  41862  Bosch WIW28300GB  2620  Washing Machines

# %%
data = data.drop(['30131', 'Washing Machines', '2620'],1 )
from sklearn.preprocessing import LabelEncoder
data = data.apply(LabelEncoder().fit_transform)
data.head()
# Out:
#    bosch wiw28300gb serie 6 8kg 1400rpm integrated washing machine white   6  \
# 0                                                641                       4
# 1                                                946                      17
# 2                                               2230                      78
# 3                                                943                       1
# 4                                                941                      26
#
#    41862  Bosch WIW28300GB
# 0      0               311
# 1      0               311
# 2      0               311
# 3      0               311
# 4      0               311

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss = []
for i in range(1, 16):
    kmeans = KMeans(i, n_init=15)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
plt.plot(wcss, 'bx-')
plt.show()

# %%
kmeans = KMeans(3)
Y_kmeans = kmeans.fit_predict(data)


from sklearn.decomposition import PCA
pca = PCA(2)
x = pca.fit_transform(data)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x[Y_kmeans==0, 0], x[Y_kmeans==0, 1], s=30, c='red', label='Cluster 1')
plt.scatter(x[Y_kmeans==1, 0], x[Y_kmeans==1, 1], s=30, c='blue', label='Cluster 2')
plt.scatter(x[Y_kmeans==2, 0], x[Y_kmeans==2, 1], s=30, c='green', label='Cluster 3')
plt.show()
