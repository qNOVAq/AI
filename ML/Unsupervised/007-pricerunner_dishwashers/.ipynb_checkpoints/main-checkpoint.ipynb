# %%
import pandas as pd
import numpy as np
data = pd.read_csv('pricerunner_dishwashers.csv')
data.head()
# Out:
#    26300 bosch sms25aw00g 60cm serie 2 freestanding dishwasher white  301  \
# 0  26301                   bosch sms25aw00g 60cm dishwasher           129
# 1  26302        bosch sms25aw00g full size dishwasher white            22
# 2  26303  bosch sms25aw00g dishwasher 60cm 12 place 5 pr...           131
# 3  26304  bosch sms25aw00g 12 place freestanding dishwas...             3
# 4  26307  bosch sms25aw00g white 2400w freestanding dish...           132
#
#    40464  Bosch SMS25AW00G White  2619  Dishwashers
# 0  40464  Bosch SMS25AW00G White  2619  Dishwashers
# 1  40464  Bosch SMS25AW00G White  2619  Dishwashers
# 2  40464  Bosch SMS25AW00G White  2619  Dishwashers
# 3  40464  Bosch SMS25AW00G White  2619  Dishwashers
# 4  40464  Bosch SMS25AW00G White  2619  Dishwashers

# %%
data = data.drop(['26300', '2619', 'Dishwashers'], 1)

# %%
from sklearn.preprocessing import LabelEncoder
data = data.apply(LabelEncoder().fit_transform)
data.head()
# Out:
#    bosch sms25aw00g 60cm serie 2 freestanding dishwasher white  301  40464  \
# 0                                                777             23      0
# 1                                                782              8      0
# 2                                                780             25      0
# 3                                                776              1      0
# 4                                                785             26      0
#
#    Bosch SMS25AW00G White
# 0                     238
# 1                     238
# 2                     238
# 3                     238
# 4                     238

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss = []

for i in range(1, 16):
    kmeans = KMeans(i , n_init=15)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)

plt.plot(wcss, 'bx-')
plt.show()

# %%
kmeans = KMeans(4)
Y_kmeans = kmeans.fit_predict(data)

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
x = pca.fit_transform(data)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x[Y_kmeans==0, 0], x[Y_kmeans==0, 1], s=30, c='red', label='Cluster 1')
plt.scatter(x[Y_kmeans==1, 0], x[Y_kmeans==1, 1], s=30, c='green', label='Cluster 2')
plt.scatter(x[Y_kmeans==2, 0], x[Y_kmeans==2, 1], s=30, c='blue', label='Cluster 3')
plt.scatter(x[Y_kmeans==3, 0], x[Y_kmeans==3, 1], s=30, c='orange', label='Cluster 4')
plt.legend()
plt.show()
