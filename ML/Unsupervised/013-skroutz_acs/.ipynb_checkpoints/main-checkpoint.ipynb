# %%
import pandas as pd 
import numpy as np
data = pd.read_csv('skroutz_acs.csv')
data.head()
# Out:
#    61975  \
# 0  61976
# 1  61977
# 2  61978
# 3  61979
# 4  61980
#
#   toyotomi htn/htg 709r32 sira hiro eco dc inverter wifi new model 2018 a /a se 6 atokes dosis 9.000 btu toac09hi7 a to  \
# 0  toyotomi hiro me wifi htn/htg 709r32 9.000 btu...
# 1  toyotomi hiro me wifi htn/htg 709r32 9.000 btu...
# 2  klimatistiko toyotomi hiro eco htn/htg 709 r32...
# 3                   toyotomi hiro eco htn/htg 709r32
# 4  toyotomi hiro eco htn/htg 709r32 klimatistiko ...
#
#    2226  104377  Toyotomi Hiro Eco HTN/HTG-709R32  2143  \
# 0   912  104377  Toyotomi Hiro Eco HTN/HTG-709R32  2143
# 1  1044  104377  Toyotomi Hiro Eco HTN/HTG-709R32  2143
# 2  1352  104377  Toyotomi Hiro Eco HTN/HTG-709R32  2143
# 3  1173  104377  Toyotomi Hiro Eco HTN/HTG-709R32  2143
# 4   606  104377  Toyotomi Hiro Eco HTN/HTG-709R32  2143
#
#    Home Air Conditioners - Inverters
# 0  Home Air Conditioners - Inverters
# 1  Home Air Conditioners - Inverters
# 2  Home Air Conditioners - Inverters
# 3  Home Air Conditioners - Inverters
# 4  Home Air Conditioners - Inverters

# %%
data = data.drop(['61975', 'Home Air Conditioners - Inverters', '2143'],1 )
from sklearn.preprocessing import LabelEncoder
data = data.apply(LabelEncoder().fit_transform)
data.head()
# Out:
#    toyotomi htn/htg 709r32 sira hiro eco dc inverter wifi new model 2018 a /a se 6 atokes dosis 9.000 btu toac09hi7 a to  \
# 0                                              11093
# 1                                              11092
# 2                                               7387
# 3                                              11018
# 4                                              11029
#
#    2226  104377  Toyotomi Hiro Eco HTN/HTG-709R32
# 0    18       0                               502
# 1    25       0                               502
# 2    44       0                               502
# 3    32       0                               502
# 4     9       0                               502

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss = []
for i in range(1, 16):
    kmeans = KMeans(i, n_init=15)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
plt.plot(wcss, 'bx-')
plt.show()

# %%
kmeans = KMeans(3)
Y_kmeans = kmeans.fit_predict(data)


from sklearn.decomposition import PCA
pca = PCA(2)
x = pca.fit_transform(data)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x[Y_kmeans==0, 0], x[Y_kmeans==0, 1], s=30, c='red', label='Cluster 1')
plt.scatter(x[Y_kmeans==1, 0], x[Y_kmeans==1, 1], s=30, c='blue', label='Cluster 2')
plt.scatter(x[Y_kmeans==2, 0], x[Y_kmeans==2, 1], s=30, c='green', label='Cluster 3')
plt.show()
