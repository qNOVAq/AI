# %%
import pandas as pd
import numpy as np
data = pd.read_csv('pricerunner_cpus.csv')
data.head()
# Out:
#    13771 amd ryzen 7 eight core 1700x 3.80ghz socket am4 processor retail  \
# 0  13772         amd ryzen 7 1700x 8 core am4 cpu/processor
# 1  13773         amd ryzen 7 1700x 3.4ghz 16mb l3 processor
# 2  13774  amd ryzen 7 1700x 95 w 8 core/16 threads 3.8gh...
# 3  13775  open box amd ryzen 7 1700x 3.8 ghz 8 core 95w ...
# 4  13776  amd ryzen 7 1700x 8 core 16 thread am4 cpu/pro...
#
#      5  5851  AMD Ryzen 7 1700X 3.4GHz Box  2615  CPUs
# 0    4  5851  AMD Ryzen 7 1700X 3.4GHz Box  2615  CPUs
# 1   14  5851  AMD Ryzen 7 1700X 3.4GHz Box  2615  CPUs
# 2    3  5851  AMD Ryzen 7 1700X 3.4GHz Box  2615  CPUs
# 3   30  5851  AMD Ryzen 7 1700X 3.4GHz Box  2615  CPUs
# 4  121  5851  AMD Ryzen 7 1700X 3.4GHz Box  2615  CPUs

# %%
data = data.drop(['13771', 'CPUs', '2615'], 1)

# %%
from sklearn.preprocessing import LabelEncoder
data = data.apply(LabelEncoder().fit_transform)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss = []
for i in range(1, 16):
    kmeans = KMeans(i , n_init=15)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
plt.plot(wcss, 'bx-')
plt.show()

# %%
kmeans = KMeans(4)
Y_kmeans = kmeans.fit_predict(data)

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
x = pca.fit_transform(data)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x[Y_kmeans==0, 0], x[Y_kmeans==0, 1], s=30, c='red', label='Cluster 1')
plt.scatter(x[Y_kmeans==1, 0], x[Y_kmeans==1, 1], s=30, c='green', label='Cluster 2')
plt.scatter(x[Y_kmeans==2, 0], x[Y_kmeans==2, 1], s=30, c='blue', label='Cluster 3')
plt.scatter(x[Y_kmeans==3, 0], x[Y_kmeans==3, 1], s=30, c='orange', label='Cluster 4')
plt.scatter(x[Y_kmeans==4, 0], x[Y_kmeans==4, 1], s=30, c='black', label='Cluster 5')
plt.scatter(x[Y_kmeans==5, 0], x[Y_kmeans==5, 1], s=30, c='lightblue', label='Cluster 6')
plt.legend()
plt.show()
