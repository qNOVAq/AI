# %%
import pandas as pd
import numpy as np
data = pd.read_csv('pricerunner_microwaves.csv')
data.head()
# Out:
#    23766 bosch hmt72m450b silver freestanding microwave oven  132  39647  \
# 0  23767  bosch hmt72m450b 17 litre microwave with grill...   289  39647
# 1  23768                                   bosch hmt72m450b   290  39647
# 2  23769  bosch hmt72m450b 800w microwave oven with 5 po...    32  39647
# 3  23770  bosch free standing microwave oven in brushed ...    31  39647
# 4  23771  bosch hmt72m450b compact microwave oven in sta...   128  39647
#
#    Bosch HMT72M450B Stainless Steel  2618  Microwaves
# 0  Bosch HMT72M450B Stainless Steel  2618  Microwaves
# 1  Bosch HMT72M450B Stainless Steel  2618  Microwaves
# 2  Bosch HMT72M450B Stainless Steel  2618  Microwaves
# 3  Bosch HMT72M450B Stainless Steel  2618  Microwaves
# 4  Bosch HMT72M450B Stainless Steel  2618  Microwaves

# %%
data = data.drop(['23766', 'Microwaves', '2618'],1)

# %%
from sklearn.preprocessing import LabelEncoder
data = data.apply(LabelEncoder().fit_transform)
data.head()
# Out:
#    bosch hmt72m450b silver freestanding microwave oven  132  39647  \
# 0                                                326     60      0
# 1                                                324     61      0
# 2                                                327     13      0
# 3                                                301     12      0
# 4                                                329     32      0
#
#    Bosch HMT72M450B Stainless Steel
# 0                               110
# 1                               110
# 2                               110
# 3                               110
# 4                               110

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss = []

for i in range(1, 16):
    kmeans = KMeans(i, n_init=15)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
plt.plot(wcss, 'bx-')
plt.show()

# %%
kmeans = KMeans(3)
Y_kmeans = kmeans.fit_predict(data)

from sklearn.decomposition import PCA
pca = PCA(2)
x = pca.fit_transform(data)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x[Y_kmeans==0, 0], x[Y_kmeans==0, 1], s=30, c='red', label='Cluster 1')
plt.scatter(x[Y_kmeans==1, 0], x[Y_kmeans==1, 1], s=30, c='green', label='Cluster 2')
plt.scatter(x[Y_kmeans==2, 0], x[Y_kmeans==2, 1], s=30, c='blue', label='Cluster 3')
plt.show()
