# %%
import pandas as pd 
import numpy as np
data = pd.read_csv('pricerunner_refrigerators.csv')
data.head()
# Out:
#    34726                 bosch gud15a50gb/02 freezer drawer    3  43262  \
# 0  34729                        bosch gud15a50gb/gud15a50gb   98  43262
# 1  34730  bosch gud15a50gb serie 6 integrated built unde...  301  43262
# 2  34731         bosch serie 6 built under freezer in white   31  43262
# 3  34732  bosch gud15a50gb classixx built in under integ...  128  43262
# 4  34733        bosch gud15a50gb built under 4 star freezer  125  43262
#
#    Bosch GUD15A50GB Integrated  2621  Freezers
# 0  Bosch GUD15A50GB Integrated  2621  Freezers
# 1  Bosch GUD15A50GB Integrated  2621  Freezers
# 2  Bosch GUD15A50GB Integrated  2621  Freezers
# 3  Bosch GUD15A50GB Integrated  2621  Freezers
# 4  Bosch GUD15A50GB Integrated  2621  Freezers

# %%
data = data.drop(['34726', 'Freezers', '2621'], 1)

# %%
from sklearn.preprocessing import LabelEncoder
data = data.apply(LabelEncoder().fit_transform)
data.head()
# Out:
#    bosch gud15a50gb/02 freezer drawer   3  43262  Bosch GUD15A50GB Integrated
# 0                                1538  19      0                          605
# 1                                1536  68      0                          605
# 2                                2484  10      0                          605
# 3                                1534  25      0                          605
# 4                                1531  23      0                          605

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss = []

for i in range(1, 16):
    kmeans = KMeans(i, n_init=15)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
plt.plot(wcss, 'bx-')
plt.show()

# %%
kmeans = KMeans(3)
Y_kmeans = kmeans.fit_predict(data)

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
x = pca.fit_transform(data)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x[Y_kmeans==0, 0], x[Y_kmeans==0, 1], s=30, c='red', label='Cluster 1')
plt.scatter(x[Y_kmeans==1, 0], x[Y_kmeans==1, 1], s=30, c='green', label='Cluster 2')
plt.scatter(x[Y_kmeans==2, 0], x[Y_kmeans==2, 1], s=30, c='blue', label='Cluster 3')
plt.legend()
plt.show()
